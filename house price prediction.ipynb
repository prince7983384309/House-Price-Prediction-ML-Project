# %% [markdown]
# # Import Libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Train dataset handling

# %%
# Read the dataset.

df = pd.read_csv('train.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# drop the id.
df = df.drop(['Id'], axis=1)
df = df.drop(['Alley'], axis=1)
df = df.drop(['PoolQC'], axis=1)
df = df.drop(['Fence'], axis=1)
df = df.drop(['MiscFeature'], axis=1)
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
# check the information.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
# check the duplicates values.

duplicates = df.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
# check the null values columns.
nan_cols = [i for i in df.columns if df[i].isnull().any()]
nan_cols
# Out:
# ['LotFrontage',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
# check columns null values.

print(df['LotFrontage'].isnull().sum())
print(df['MasVnrType'].isnull().sum())
print(df['MasVnrArea'].isnull().sum())
print(df['BsmtQual'].isnull().sum())
print(df['BsmtCond'].isnull().sum())
print(df['BsmtExposure'].isnull().sum())
print(df['BsmtFinType1'].isnull().sum())
print(df['BsmtFinType2'].isnull().sum())
print(df['Electrical'].isnull().sum())
print(df['FireplaceQu'].isnull().sum())
print(df['GarageType'].isnull().sum())
print(df['GarageYrBlt'].isnull().sum())
print(df['GarageFinish'].isnull().sum())
print(df['GarageQual'].isnull().sum())
print(df['GarageCond'].isnull().sum())
# Out:
# 259
# 8
# 8
# 37
# 37
# 38
# 37
# 38
# 1
# 690
# 81
# 81
# 81
# 81
# 81

# %%
# describe the dataset.
df.describe(include='all').T
# Out:
#                 count unique     top  freq          mean           std  \
# MSSubClass     1460.0    NaN     NaN   NaN      56.89726     42.300571
# MSZoning         1460      5      RL  1151           NaN           NaN
# LotFrontage    1201.0    NaN     NaN   NaN     70.049958     24.284752
# LotArea        1460.0    NaN     NaN   NaN  10516.828082   9981.264932
# Street           1460      2    Pave  1454           NaN           NaN
# ...               ...    ...     ...   ...           ...           ...
# MoSold         1460.0    NaN     NaN   NaN      6.321918      2.703626
# YrSold         1460.0    NaN     NaN   NaN   2007.815753      1.328095
# SaleType         1460      9      WD  1267           NaN           NaN
# SaleCondition    1460      6  Normal  1198           NaN           NaN
# SalePrice      1460.0    NaN     NaN   NaN  180921.19589  79442.502883
#
#                    min       25%       50%       75%       max
# ...

# %%
df['LotFrontage'].fillna(df['LotFrontage'].mean(), inplace = True)

# %%
df['MasVnrType'].fillna(df['MasVnrType'].mode(), inplace = True)

# %%
df['MasVnrArea'].fillna(df['MasVnrArea'].mean(), inplace = True)

# %%
df['BsmtQual'].fillna(df['BsmtQual'].mode(), inplace = True)

# %%
df['BsmtCond'].fillna(df['BsmtCond'].mode(), inplace = True)

# %%
df['BsmtExposure'].fillna(df['BsmtExposure'].mode(), inplace = True)

# %%
df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode(), inplace = True)

# %%
df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode(), inplace = True)

# %%
df['Electrical'].fillna(df['Electrical'].mode(), inplace = True)

# %%
df['FireplaceQu'].fillna(df['FireplaceQu'].mode(), inplace = True)

# %%
df['GarageType'].fillna(df['GarageType'].mode(), inplace = True)

# %%
df['GarageYrBlt'].fillna(df['GarageYrBlt'].mode(), inplace = True)

# %%
df['GarageFinish'].fillna(df['GarageFinish'].mode(), inplace = True)

# %%
df['GarageQual'].fillna(df['GarageQual'].mode(), inplace = True)

# %%
df['GarageCond'].fillna(df['GarageCond'].mode(), inplace = True)

# %%
# lets check the null values after performing.
df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64

# %%
sel_cols = (df.select_dtypes(include='object'))
sel_cols
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# ...

# %%
for col in df.select_dtypes(include='object').columns:
    print('count_values of {}\n is\n {} '.format(col,df[col].value_counts()))
# Out:
# count_values of MSZoning
#  is
#  RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# count_values of Street
#  is
#  Pave    1454
# Grvl       6
# Name: Street, dtype: int64
# count_values of LotShape
#  is
#  Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64
# count_values of LandContour
#  is
#  Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
# count_values of Utilities
#  is
#  AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64
# count_values of LotConfig
#  is
#  Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
# count_values of LandSlope
#  is
#  Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
# count_values of Neighborhood
#  is
#  NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# ...

# %%
# change the dtypes of object columns.

for feature in df.columns: 
    if df[feature].dtype == 'object': 
        df[feature] = pd.Categorical(df[feature]).codes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # change the dtypes of object columns.
# ----> 3 for feature in df.columns:
#       4     if df[feature].dtype == 'object':
#       5         df[feature] = pd.Categorical(df[feature]).codes
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   int8
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   int8
#  5   LotShape       1460 non-null   int8
#  6   LandContour    1460 non-null   int8
#  7   Utilities      1460 non-null   int8
#  8   LotConfig      1460 non-null   int8
#  9   LandSlope      1460 non-null   int8
#  10  Neighborhood   1460 non-null   int8
#  11  Condition1     1460 non-null   int8
#  12  Condition2     1460 non-null   int8
#  13  BldgType       1460 non-null   int8
#  14  HouseStyle     1460 non-null   int8
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
#  17  YearBuilt      1460 non-null   int64
# ...

# %%
df.fillna(0)
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# 4             60         3         84.0    14260       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0     7917       1         3
# 1456          20         3         85.0    13175       1         3
# 1457          70         3         66.0     9042       1         3
# 1458          20         3         68.0     9717       1         3
# 1459          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0               3          0          4          0             5           2
# ...

# %%
 # capture the target column ("SalePrice") into separate vectors for training set and test set

X = df.drop("SalePrice" , axis=1)

y = df.pop("SalePrice")

# %%
X = X.replace(np.nan, 0)
X
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# 4             60         3         84.0    14260       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0     7917       1         3
# 1456          20         3         85.0    13175       1         3
# 1457          70         3         66.0     9042       1         3
# 1458          20         3         68.0     9717       1         3
# 1459          20         3         75.0     9937       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0               3          0          4          0             5           2
# ...

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# # splitting data into training and test set for independent attributes

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state=1)

# %%
# apply multilinear regression.

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1168, 75)
# (292, 75)
# (1168,)
# (292,)

# %%
# Predict the X_test .
#Predicting the Test set result;  
y_pred= regressor.predict(X_test)
#y_pred

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.82163115392306

# %% [markdown]
# # Test dataset handling

# %%
# read the test file.
test_file = pd.read_csv('test.csv')

# %%
test_file.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
duplicates = df.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
# check the null values columns.
nan_col = [i for i in test_file.columns if test_file[i].isnull().any()]
nan_col
# Out:
# ['MSZoning',
#  'LotFrontage',
#  'Alley',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType']

# %%
print(test_file['MSZoning'].isnull().sum())
print(test_file['LotFrontage'].isnull().sum())
print(test_file['Alley'].isnull().sum())
print(test_file['Utilities'].isnull().sum())
print(test_file['Exterior1st'].isnull().sum())
print(test_file['Exterior2nd'].isnull().sum())
print(test_file['MasVnrType'].isnull().sum())
print(test_file['MasVnrArea'].isnull().sum())
print(test_file['BsmtQual'].isnull().sum())
print(test_file['BsmtCond'].isnull().sum())
print(test_file['BsmtExposure'].isnull().sum())
print(test_file['BsmtFinType1'].isnull().sum())
print(test_file['BsmtFinSF1'].isnull().sum())
print(test_file['BsmtFinType2'].isnull().sum())
print(test_file['BsmtFinSF2'].isnull().sum())
print(test_file['BsmtUnfSF'].isnull().sum())
print(test_file['TotalBsmtSF'].isnull().sum())
print(test_file['BsmtFullBath'].isnull().sum())
print(test_file['BsmtHalfBath'].isnull().sum())
print(test_file['KitchenQual'].isnull().sum())
print(test_file['Functional'].isnull().sum())
print(test_file['GarageType'].isnull().sum())
print(test_file['GarageYrBlt'].isnull().sum())
print(test_file['GarageFinish'].isnull().sum())
print(test_file['GarageCars'].isnull().sum())
print(test_file['GarageArea'].isnull().sum())
print(test_file['GarageQual'].isnull().sum())
print(test_file['GarageCond'].isnull().sum())
print(test_file['PoolQC'].isnull().sum())
print(test_file['Fence'].isnull().sum())
print(test_file['MiscFeature'].isnull().sum())
print(test_file['SaleType'].isnull().sum())
# Out:
# 4
# 227
# 1352
# 2
# 1
# 1
# 16
# 15
# 44
# 45
# 44
# 42
# 1
# 42
# 1
# 1
# 1
# 2
# 2
# 1
# 2
# 76
# 78
# 78
# 1
# 1
# 78
# 78
# 1456
# 1169
# 1408
# 1

# %%
test_file = test_file.drop(['Id'], axis=1)
test_file = test_file.drop(['Alley'], axis=1)
test_file = test_file.drop(['PoolQC'], axis=1)
test_file = test_file.drop(['Fence'], axis=1)
test_file = test_file.drop(['MiscFeature'], axis=1)
pd.set_option('display.max_columns', None)
test_file
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             20       RH         80.0    11622   Pave      Reg         Lvl
# 1             20       RL         81.0    14267   Pave      IR1         Lvl
# 2             60       RL         74.0    13830   Pave      IR1         Lvl
# 3             60       RL         78.0     9978   Pave      IR1         Lvl
# 4            120       RL         43.0     5005   Pave      IR1         HLS
# ...          ...      ...          ...      ...    ...      ...         ...
# 1454         160       RM         21.0     1936   Pave      Reg         Lvl
# 1455         160       RM         21.0     1894   Pave      Reg         Lvl
# 1456          20       RL        160.0    20000   Pave      Reg         Lvl
# 1457          85       RL         62.0    10441   Pave      Reg         Lvl
# 1458          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %%
test_file.describe(include='all').T
# Out:
#                 count unique     top  freq         mean          std     min  \
# MSSubClass     1459.0    NaN     NaN   NaN    57.378341     42.74688    20.0
# MSZoning         1455      5      RL  1114          NaN          NaN     NaN
# LotFrontage    1232.0    NaN     NaN   NaN    68.580357    22.376841    21.0
# LotArea        1459.0    NaN     NaN   NaN  9819.161069  4955.517327  1470.0
# Street           1459      2    Pave  1453          NaN          NaN     NaN
# ...               ...    ...     ...   ...          ...          ...     ...
# MiscVal        1459.0    NaN     NaN   NaN    58.167923   630.806978     0.0
# MoSold         1459.0    NaN     NaN   NaN     6.104181     2.722432     1.0
# YrSold         1459.0    NaN     NaN   NaN  2007.769705      1.30174  2006.0
# SaleType         1458      9      WD  1258          NaN          NaN     NaN
# SaleCondition    1459      6  Normal  1204          NaN          NaN     NaN
#
# ...

# %%
test_file['MSZoning'].fillna(test_file['MSZoning'].mode(), inplace = True)

# %%
test_file['LotFrontage'].fillna(test_file['LotFrontage'].mean(), inplace = True)

# %%
test_file['Utilities'].fillna(test_file['Utilities'].mode(), inplace = True)

# %%
test_file['Exterior1st'].fillna(test_file['Exterior1st'].mode(), inplace = True)

# %%
test_file['Exterior2nd'].fillna(test_file['Exterior2nd'].mode(), inplace = True)

# %%
test_file['MasVnrType'].fillna(test_file['MasVnrType'].mode(), inplace = True)

# %%
test_file['MasVnrArea'].fillna(test_file['MasVnrArea'].mean(), inplace = True)

# %%
test_file['BsmtQual'].fillna(test_file['BsmtQual'].mode(), inplace = True)

# %%
test_file['BsmtCond'].fillna(test_file['BsmtCond'].mode(), inplace = True)

# %%
test_file['BsmtExposure'].fillna(test_file['BsmtExposure'].mode(), inplace = True)

# %%
test_file['BsmtFinType1'].fillna(test_file['BsmtFinType1'].mode(), inplace = True)

# %%
test_file['BsmtFinSF1'].fillna(test_file['BsmtFinSF1'].mean(), inplace = True)

# %%
test_file['BsmtFinType2'].fillna(test_file['BsmtFinType2'].mode(), inplace = True)

# %%
test_file['BsmtFinSF2'].fillna(test_file['BsmtFinSF2'].mean(), inplace = True)

# %%
test_file['BsmtUnfSF'].fillna(test_file['BsmtUnfSF'].mean(), inplace = True)

# %%
test_file['TotalBsmtSF'].fillna(test_file['TotalBsmtSF'].mean(), inplace = True)

# %%
test_file['BsmtFullBath'].fillna(test_file['BsmtFullBath'].mode(), inplace = True)

# %%
test_file['BsmtHalfBath'].fillna(test_file['BsmtHalfBath'].mode(), inplace = True)

# %%
test_file['KitchenQual'].fillna(test_file['KitchenQual'].mode(), inplace = True)

# %%
test_file['Functional'].fillna(test_file['Functional'].mode(), inplace = True)

# %%
test_file['FireplaceQu'].fillna(test_file['FireplaceQu'].mode(), inplace = True)

# %%
test_file['GarageType'].fillna(test_file['GarageType'].mode(), inplace = True)

# %%
test_file['GarageYrBlt'].fillna(test_file['GarageYrBlt'].mode(), inplace = True)

# %%
test_file['GarageFinish'].fillna(test_file['GarageFinish'].mode(), inplace = True)

# %%
test_file['GarageCars'].fillna(test_file['GarageCars'].mode(), inplace = True)

# %%
test_file['GarageArea'].fillna(test_file['GarageArea'].mean(), inplace = True)

# %%
test_file['GarageQual'].fillna(test_file['GarageQual'].mode(), inplace = True)

# %%
test_file['GarageCond'].fillna(test_file['GarageCond'].mode(), inplace = True)

# %%
test_file['SaleType'].fillna(test_file['SaleType'].mode(), inplace = True)

# %%
# change the dtypes of object columns.

for feature in test_file.columns: 
    if test_file[feature].dtype == 'object': 
        test_file[feature] = pd.Categorical(test_file[feature]).codes

# %%
test_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   int64
#  1   MSZoning       1459 non-null   int8
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   int8
#  5   LotShape       1459 non-null   int8
#  6   LandContour    1459 non-null   int8
#  7   Utilities      1459 non-null   int8
#  8   LotConfig      1459 non-null   int8
#  9   LandSlope      1459 non-null   int8
#  10  Neighborhood   1459 non-null   int8
#  11  Condition1     1459 non-null   int8
#  12  Condition2     1459 non-null   int8
#  13  BldgType       1459 non-null   int8
#  14  HouseStyle     1459 non-null   int8
#  15  OverallQual    1459 non-null   int64
#  16  OverallCond    1459 non-null   int64
#  17  YearBuilt      1459 non-null   int64
# ...

# %%
test_file = test_file.replace(np.nan, 0)

# %%
test_file.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 75, dtype: int64

# %%
final_prediction= regressor.predict(test_file)

# %%
final_prediction
# Out:
# array([102748.64275558, 162976.64078531, 163948.14564156, ...,
#        139976.19166868, 136045.99112715, 240987.22990751])

# %%
pred_df= pd.DataFrame(final_prediction)
pred_df
# Out:
#                   0
# 0     102748.642756
# 1     162976.640785
# 2     163948.145642
# 3     187835.255962
# 4     188950.256500
# ...             ...
# 1454   80615.868842
# 1455   57142.013167
# 1456  139976.191669
# 1457  136045.991127
# 1458  240987.229908
#
# [1459 rows x 1 columns]

# %%
pred_df.to_csv('subbmission.csv')
